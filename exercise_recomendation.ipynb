# %% [markdown]
# ## Recommendation To Improve Language Learning

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Flatten, Dense, Concatenate, Dot, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# Load the data
df = pd.read_csv('data.csv')

# Preprocessing
le = LabelEncoder()
categorical_columns = ['category', 'difficulty', 'cultural_context', 'user_country', 'user_age_group', 'user_proficiency']
for col in categorical_columns:
    df[col] = le.fit_transform(df[col])

df['user_id'] = le.fit_transform(df['user_id'])
df['exercise_id'] = le.fit_transform(df['exercise_id'])

# Create a mapping from exercise_id to cultural_context
exercise_to_context = {
    101: 'Anime',
    102: 'Kpop',
    103: 'Kdrama',
    104: 'Horror',
    105: 'Sitcom',
    106: 'Memes',
    107: 'Sports',
    108: 'Informative'
}

# Splitting the data
train, test = train_test_split(df, test_size=0.2, random_state=42)

# Model parameters
n_users = df['user_id'].nunique()
n_exercises = df['exercise_id'].nunique()
n_factors = 50
n_categories = df['category'].nunique()
n_difficulties = df['difficulty'].nunique()
n_cultural_contexts = df['cultural_context'].nunique()
n_countries = df['user_country'].nunique()
n_age_groups = df['user_age_group'].nunique()
n_proficiencies = df['user_proficiency'].nunique()

# Model architecture
user_input = Input(shape=(1,), name='user_input')
exercise_input = Input(shape=(1,), name='exercise_input')
category_input = Input(shape=(1,), name='category_input')
difficulty_input = Input(shape=(1,), name='difficulty_input')
cultural_context_input = Input(shape=(1,), name='cultural_context_input')
user_country_input = Input(shape=(1,), name='user_country_input')
user_age_group_input = Input(shape=(1,), name='user_age_group_input')
user_proficiency_input = Input(shape=(1,), name='user_proficiency_input')

# Collaborative filtering part
user_embedding = Embedding(n_users, n_factors, embeddings_regularizer=l2(1e-6))(user_input)
exercise_embedding = Embedding(n_exercises, n_factors, embeddings_regularizer=l2(1e-6))(exercise_input)
user_vec = Flatten()(user_embedding)
exercise_vec = Flatten()(exercise_embedding)
cf_output = Dot(axes=1)([user_vec, exercise_vec])

# Content-based part
category_embedding = Embedding(n_categories, 10)(category_input)
difficulty_embedding = Embedding(n_difficulties, 5)(difficulty_input)
cultural_context_embedding = Embedding(n_cultural_contexts, 10)(cultural_context_input)
user_country_embedding = Embedding(n_countries, 10)(user_country_input)
user_age_group_embedding = Embedding(n_age_groups, 5)(user_age_group_input)
user_proficiency_embedding = Embedding(n_proficiencies, 5)(user_proficiency_input)

concat = Concatenate()([
    Flatten()(category_embedding),
    Flatten()(difficulty_embedding),
    Flatten()(cultural_context_embedding),
    Flatten()(user_country_embedding),
    Flatten()(user_age_group_embedding),
    Flatten()(user_proficiency_embedding)
])

# More complex ANN architecture
dense1 = Dense(64, activation='relu')(concat)
bn1 = BatchNormalization()(dense1)
dense2 = Dense(32, activation='relu')(bn1)
bn2 = BatchNormalization()(dense2)
dropout1 = Dropout(0.3)(bn2)
dense3 = Dense(16, activation='relu')(dropout1)
bn3 = BatchNormalization()(dense3)
dense4 = Dense(8, activation='relu')(bn3)
bn4 = BatchNormalization()(dense4)
cb_output = Dense(1)(bn4)

# Combine CF and CB outputs
combined_output = Dense(1)(Concatenate()([cf_output, cb_output]))

model = Model(
    inputs=[user_input, exercise_input, category_input, difficulty_input, cultural_context_input, user_country_input, user_age_group_input, user_proficiency_input],
    outputs=combined_output
)

model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Training the model
history = model.fit(
    [train['user_id'], train['exercise_id'], train['category'], train['difficulty'], train['cultural_context'], train['user_country'], train['user_age_group'], train['user_proficiency']],
    train['rating'],
    epochs=200,
    batch_size=32,
    validation_split=0.1,
    callbacks=[early_stopping],
    verbose=1
)

# Function to get top N recommendations for a user
def get_top_n_recommendations(user_id, n=2):
    user_exercises = df[df['user_id'] == user_id]['exercise_id'].unique()
    all_exercises = df['exercise_id'].unique()
    exercises_to_predict = np.setdiff1d(all_exercises, user_exercises)
    
    if len(exercises_to_predict) == 0:
        return []
    
    user_data = df[df['user_id'] == user_id].iloc[0]
    user_vector = np.array([user_id] * len(exercises_to_predict))
    exercise_vector = exercises_to_predict
    category_vector = np.array([user_data['category']] * len(exercises_to_predict))
    difficulty_vector = np.array([user_data['difficulty']] * len(exercises_to_predict))
    cultural_context_vector = np.array([user_data['cultural_context']] * len(exercises_to_predict))
    user_country_vector = np.array([user_data['user_country']] * len(exercises_to_predict))
    user_age_group_vector = np.array([user_data['user_age_group']] * len(exercises_to_predict))
    user_proficiency_vector = np.array([user_data['user_proficiency']] * len(exercises_to_predict))
    
    predictions = model.predict([user_vector, exercise_vector, category_vector, difficulty_vector, cultural_context_vector, user_country_vector, user_age_group_vector, user_proficiency_vector])
    top_n_indices = predictions.flatten().argsort()[-n:][::-1]
    recommended_exercises = exercises_to_predict[top_n_indices]
    return [exercise_to_context.get(ex + 101, 'Unknown') for ex in recommended_exercises]

# Cold start strategy
def cold_start_recommendation(user_data, n=2):
    # For new users, recommend based on their proficiency level and country
    similar_users = df[
        (df['user_proficiency'] == user_data['user_proficiency']) &
        (df['user_country'] == user_data['user_country'])
    ]
    
    if len(similar_users) == 0:
        # If no similar users found, recommend popular exercises
        popular_exercises = df.groupby('exercise_id')['rating'].mean().sort_values(ascending=False)
        recommended_exercises = popular_exercises.head(n).index.tolist()
    else:
        # Recommend exercises popular among similar users
        popular_exercises = similar_users.groupby('exercise_id')['rating'].mean().sort_values(ascending=False)
        recommended_exercises = popular_exercises.head(n).index.tolist()
    
    return [exercise_to_context.get(ex + 101, 'Unknown') for ex in recommended_exercises]

# Example usage for existing user
user_id = 0  # Assuming user IDs start from 0 after encoding
top_recommendations = get_top_n_recommendations(user_id, n=2)
print(f"Top exercise recommendations for user {user_id}: {top_recommendations}")

# Example usage for cold start (new user)
new_user_data = {
    'user_proficiency': df['user_proficiency'].mode().iloc[0],  # Most common proficiency
    'user_country': df['user_country'].mode().iloc[0]  # Most common country
}
cold_start_recs = cold_start_recommendation(new_user_data)
print(f"Cold start recommendations: {cold_start_recs}")
# Out:
# Epoch 1/200
# d:\WORKSPACE\content-based-filtering-scoreup\venv\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['user_input', 'exercise_input', 'category_input', 'difficulty_input', 'cultural_context_input', 'user_country_input', 'user_age_group_input', 'user_proficiency_input']. Received: the structure of inputs=('*', '*', '*', '*', '*', '*', '*', '*')
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 13.8610 - val_loss: 16.9906
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 13.7922 - val_loss: 16.9719
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 13.8032 - val_loss: 16.9526
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 13.7696 - val_loss: 16.9335
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.5934 - val_loss: 16.9148
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 13.5705 - val_loss: 16.8923
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 13.5711 - val_loss: 16.8730
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 13.4686 - val_loss: 16.8501
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 13.5190 - val_loss: 16.8272
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 13.4645 - val_loss: 16.8036
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 13.4199 - val_loss: 16.7763
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 13.4551 - val_loss: 16.7488
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 13.3502 - val_loss: 16.7236
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 13.4119 - val_loss: 16.6955
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.2991 - val_loss: 16.6685
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 13.3036 - val_loss: 16.6395
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 13.2587 - val_loss: 16.6096
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 13.2701 - val_loss: 16.5811
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 13.1930 - val_loss: 16.5550
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 13.1951 - val_loss: 16.5268
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 13.1835 - val_loss: 16.4984
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 13.2253 - val_loss: 16.4691
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 13.0929 - val_loss: 16.4364
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 13.0808 - val_loss: 16.4064
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.0861 - val_loss: 16.3743
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 13.1055 - val_loss: 16.3426
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 12.9872 - val_loss: 16.3129
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.0025 - val_loss: 16.2789
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 13.0745 - val_loss: 16.2425
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 12.9876 - val_loss: 16.2063
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 12.9461 - val_loss: 16.1698
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 12.9610 - val_loss: 16.1336
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 12.8391 - val_loss: 16.0945
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.8837 - val_loss: 16.0538
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 12.8017 - val_loss: 16.0131
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 12.7736 - val_loss: 15.9712
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 12.7465 - val_loss: 15.9333
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 12.7324 - val_loss: 15.8915
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 12.7492 - val_loss: 15.8509
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 12.6806 - val_loss: 15.8017
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 12.7115 - val_loss: 15.7572
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.6881 - val_loss: 15.7076
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 12.5368 - val_loss: 15.6581
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 12.5374 - val_loss: 15.6102
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 12.6107 - val_loss: 15.5559
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 12.5115 - val_loss: 15.5062
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 12.4306 - val_loss: 15.4552
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 12.4656 - val_loss: 15.4066
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 12.4486 - val_loss: 15.3555
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.3727 - val_loss: 15.3051
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 12.3295 - val_loss: 15.2547
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 12.2765 - val_loss: 15.1998
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.3118 - val_loss: 15.1461
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.3052 - val_loss: 15.0973
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.2214 - val_loss: 15.0424
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.1864 - val_loss: 14.9892
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.1516 - val_loss: 14.9350
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 12.1120 - val_loss: 14.8791
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 12.0674 - val_loss: 14.8210
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 12.0373 - val_loss: 14.7614
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.0727 - val_loss: 14.7007
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 11.9763 - val_loss: 14.6425
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 11.9592 - val_loss: 14.5810
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 11.9021 - val_loss: 14.5176
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 11.8431 - val_loss: 14.4542
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 11.8346 - val_loss: 14.3904
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 11.7827 - val_loss: 14.3278
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 11.8384 - val_loss: 14.2617
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 11.6841 - val_loss: 14.1986
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 11.6733 - val_loss: 14.1338
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 11.6586 - val_loss: 14.0675
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 11.6045 - val_loss: 14.0026
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 11.5169 - val_loss: 13.9403
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 11.4742 - val_loss: 13.8723
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 11.4228 - val_loss: 13.8049
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 11.3764 - val_loss: 13.7333
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 11.3329 - val_loss: 13.6639
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 11.2947 - val_loss: 13.5914
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 11.2837 - val_loss: 13.5174
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 11.2547 - val_loss: 13.4472
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 11.1929 - val_loss: 13.3772
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 11.1687 - val_loss: 13.3037
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 11.1136 - val_loss: 13.2283
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 10.9810 - val_loss: 13.1506
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 10.9355 - val_loss: 13.0726
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 10.9026 - val_loss: 12.9961
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 10.8254 - val_loss: 12.9181
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 10.8211 - val_loss: 12.8392
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 10.7557 - val_loss: 12.7613
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 10.7648 - val_loss: 12.6831
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 10.6449 - val_loss: 12.5975
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 10.6089 - val_loss: 12.5156
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 10.5680 - val_loss: 12.4359
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 10.5031 - val_loss: 12.3494
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 10.3922 - val_loss: 12.2654
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 10.3582 - val_loss: 12.1757
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 10.3035 - val_loss: 12.0855
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 10.3338 - val_loss: 12.0022
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 10.2549 - val_loss: 11.9138
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 10.0830 - val_loss: 11.8215
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 10.0348 - val_loss: 11.7403
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 9.9490 - val_loss: 11.6511
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 10.0044 - val_loss: 11.5621
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 9.8219 - val_loss: 11.4700
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 9.7890 - val_loss: 11.3827
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 9.7948 - val_loss: 11.3008
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 9.6536 - val_loss: 11.2170
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 9.5827 - val_loss: 11.1265
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 9.5116 - val_loss: 11.0383
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 9.4353 - val_loss: 10.9511
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 9.4616 - val_loss: 10.8643
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 9.3230 - val_loss: 10.7717
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 9.2385 - val_loss: 10.6811
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 9.1839 - val_loss: 10.5884
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 9.0339 - val_loss: 10.4931
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 8.9525 - val_loss: 10.3992
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 8.9126 - val_loss: 10.3034
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 8.8381 - val_loss: 10.2066
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 8.7408 - val_loss: 10.1091
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 8.7225 - val_loss: 10.0192
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 8.6071 - val_loss: 9.9260
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 8.5257 - val_loss: 9.8235
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 8.4418 - val_loss: 9.7218
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 8.3509 - val_loss: 9.6205
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 8.2744 - val_loss: 9.5255
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 8.1733 - val_loss: 9.4261
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 8.0966 - val_loss: 9.3290
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 7.9948 - val_loss: 9.2338
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 7.8906 - val_loss: 9.1377
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 7.9010 - val_loss: 9.0367
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 7.8291 - val_loss: 8.9418
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 7.6521 - val_loss: 8.8415
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 7.5506 - val_loss: 8.7438
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 7.4711 - val_loss: 8.6471
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 7.4196 - val_loss: 8.5440
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 7.3194 - val_loss: 8.4487
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.2026 - val_loss: 8.3536
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 7.1608 - val_loss: 8.2596
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 6.9834 - val_loss: 8.1603
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 6.8987 - val_loss: 8.0605
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 6.8519 - val_loss: 7.9639
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 6.7114 - val_loss: 7.8686
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 6.5924 - val_loss: 7.7731
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 6.5290 - val_loss: 7.6686
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 6.4797 - val_loss: 7.5753
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 6.4312 - val_loss: 7.4819
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 6.2464 - val_loss: 7.3874
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 6.1607 - val_loss: 7.2830
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 6.0849 - val_loss: 7.1842
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 5.9681 - val_loss: 7.0842
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 5.8562 - val_loss: 6.9809
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 5.7566 - val_loss: 6.8792
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 5.7007 - val_loss: 6.7773
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 5.6021 - val_loss: 6.6768
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 5.5557 - val_loss: 6.5821
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 5.4108 - val_loss: 6.4934
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 5.2847 - val_loss: 6.4047
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 5.1771 - val_loss: 6.3071
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 5.0633 - val_loss: 6.2142
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 4.9725 - val_loss: 6.1153
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 4.8622 - val_loss: 6.0192
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 4.7784 - val_loss: 5.9289
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 4.6600 - val_loss: 5.8360
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 4.6088 - val_loss: 5.7403
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 4.5493 - val_loss: 5.6408
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 4.4037 - val_loss: 5.5522
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 4.2929 - val_loss: 5.4554
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 4.1919 - val_loss: 5.3608
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 4.0943 - val_loss: 5.2632
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 4.0493 - val_loss: 5.1698
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 3.9182 - val_loss: 5.0711
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 3.8209 - val_loss: 4.9757
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 3.7550 - val_loss: 4.8883
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 3.6841 - val_loss: 4.7979
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 3.5408 - val_loss: 4.7127
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 3.4471 - val_loss: 4.6252
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 3.5111 - val_loss: 4.5440
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 3.2810 - val_loss: 4.4664
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 3.2009 - val_loss: 4.3848
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 3.0967 - val_loss: 4.3038
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 3.0113 - val_loss: 4.2237
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 2.9778 - val_loss: 4.1378
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.8280 - val_loss: 4.0624
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 2.8083 - val_loss: 3.9909
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 2.6754 - val_loss: 3.9212
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 2.6046 - val_loss: 3.8448
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 2.5308 - val_loss: 3.7680
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 2.4508 - val_loss: 3.6876
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 2.3622 - val_loss: 3.6126
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2.2871 - val_loss: 3.5406
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 2.2274 - val_loss: 3.4705
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2.1679 - val_loss: 3.4014
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 2.0228 - val_loss: 3.3349
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.9657 - val_loss: 3.2681
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1.9261 - val_loss: 3.1976
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8327 - val_loss: 3.1345
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.7527 - val_loss: 3.0679
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.6921 - val_loss: 3.0001
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.6520 - val_loss: 2.9415
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.5814 - val_loss: 2.8810
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# Top exercise recommendations for user 0: ['Horror']
# Cold start recommendations: ['Kdrama', 'Horror']

# %% [markdown]
# ### Evalution

# %%
# Convert test data to numpy arrays
user_id_test = np.array(test['user_id'])
exercise_id_test = np.array(test['exercise_id'])
category_test = np.array(test['category'])
difficulty_test = np.array(test['difficulty'])
cultural_context_test = np.array(test['cultural_context'])
user_country_test = np.array(test['user_country'])
user_age_group_test = np.array(test['user_age_group'])
user_proficiency_test = np.array(test['user_proficiency'])

# Predict on test data
test_predictions = model.predict([
    user_id_test,
    exercise_id_test,
    category_test,
    difficulty_test,
    cultural_context_test,
    user_country_test,
    user_age_group_test,
    user_proficiency_test
])

# Calculate MSE and RMSE
mse = mean_squared_error(test['rating'], test_predictions)
rmse = np.sqrt(mse)

print(f"Test MSE: {mse}")
print(f"Test RMSE: {rmse}")
# Out:
# d:\WORKSPACE\content-based-filtering-scoreup\venv\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['user_input', 'exercise_input', 'category_input', 'difficulty_input', 'cultural_context_input', 'user_country_input', 'user_age_group_input', 'user_proficiency_input']. Received: the structure of inputs=('*', '*', '*', '*', '*', '*', '*', '*')
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# Test MSE: 0.6777856046786497
# Test RMSE: 0.82327735586414

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 # Plot training & validation loss values
#       4 plt.plot(history.history['loss'], label='Training Loss')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Flatten, Dense, Concatenate, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Load the data
df = pd.read_csv('data.csv')
df
# Out:
#     user_id  exercise_id       category difficulty cultural_context  \
# 0         1          101        Grammar       Easy            Anime
# 1         1          102     Vocabulary     Medium             Kpop
# 2         1          103  Pronunciation       Hard           Kdrama
# 3         2          104        Grammar       Easy           Horror
# 4         2          101     Vocabulary     Medium            Anime
# 5         2          102  Pronunciation       Hard             Kpop
# 6         3          103        Grammar       Easy           Kdrama
# 7         3          104     Vocabulary     Medium           Horror
# 8         3          101  Pronunciation       Hard            Anime
# 9         4          102        Grammar       Easy             Kpop
# 10        4          103     Vocabulary     Medium           Kdrama
# 11        4          104  Pronunciation       Hard           Horror
# 12        5          101        Grammar       Easy            Anime
# 13        5          102     Vocabulary     Medium             Kpop
# 14        5          103  Pronunciation       Hard           Kdrama
# 15        6          104        Grammar       Easy           Horror
# 16        6          101     Vocabulary     Medium            Anime
# 17        6          102  Pronunciation       Hard             Kpop
# 18        7          103        Grammar       Easy           Kdrama
# 19        7          104     Vocabulary     Medium           Horror
# 20        7          101  Pronunciation       Hard            Anime
#
#    user_country user_age_group user_proficiency  rating
# 0         Japan          18-25         Beginner       4
# 1         Japan          18-25         Beginner       3
# 2         Japan          18-25         Beginner       2
# 3         India          26-35     Intermediate       5
# 4         India          26-35     Intermediate       4
# 5         India          26-35     Intermediate       3
# 6           USA          36-45         Advanced       5
# 7           USA          36-45         Advanced       4
# 8           USA          36-45         Advanced       3
# 9   South Korea          18-25         Beginner       4
# 10  South Korea          18-25         Beginner       3
# 11  South Korea          18-25         Beginner       2
# 12        China          26-35     Intermediate       4
# 13        China          26-35     Intermediate       3
# 14        China          26-35     Intermediate       5
# 15        Japan          36-45         Advanced       4
# 16        Japan          36-45         Advanced       5
# 17        Japan          36-45         Advanced       3
# 18        India          18-25         Beginner       4
# 19        India          18-25         Beginner       3
# 20        India          18-25         Beginner       2

# %%
# Encode categorical columns
le = LabelEncoder()
categorical_columns = ['category', 'difficulty', 'cultural_context', 'user_country', 'user_age_group', 'user_proficiency']
for col in categorical_columns:
    df[col] = le.fit_transform(df[col])

# %%
train, test = train_test_split(df, test_size=0.2, random_state=42)
train
# Out:
#     user_id  exercise_id       category difficulty cultural_context  \
# 5         2          102  Pronunciation       Hard             Kpop
# 11        4          104  Pronunciation       Hard           Horror
# 3         2          104        Grammar       Easy           Horror
# 18        7          103        Grammar       Easy           Kdrama
# 16        6          101     Vocabulary     Medium            Anime
# 13        5          102     Vocabulary     Medium             Kpop
# 2         1          103  Pronunciation       Hard           Kdrama
# 9         4          102        Grammar       Easy             Kpop
# 20        7          101  Pronunciation       Hard            Anime
# 4         2          101     Vocabulary     Medium            Anime
# 12        5          101        Grammar       Easy            Anime
# 7         3          104     Vocabulary     Medium           Horror
# 10        4          103     Vocabulary     Medium           Kdrama
# 14        5          103  Pronunciation       Hard           Kdrama
# 19        7          104     Vocabulary     Medium           Horror
# 6         3          103        Grammar       Easy           Kdrama
#
#    user_country user_age_group user_proficiency  rating
# 5         India          26-35     Intermediate       3
# 11  South Korea          18-25         Beginner       2
# 3         India          26-35     Intermediate       5
# 18        India          18-25         Beginner       4
# 16        Japan          36-45         Advanced       5
# 13        China          26-35     Intermediate       3
# 2         Japan          18-25         Beginner       2
# 9   South Korea          18-25         Beginner       4
# 20        India          18-25         Beginner       2
# 4         India          26-35     Intermediate       4
# 12        China          26-35     Intermediate       4
# 7           USA          36-45         Advanced       4
# 10  South Korea          18-25         Beginner       3
# 14        China          26-35     Intermediate       5
# 19        India          18-25         Beginner       3
# 6           USA          36-45         Advanced       5

# %%
test
# Out:
#     user_id  exercise_id       category difficulty cultural_context  \
# 0         1          101        Grammar       Easy            Anime
# 17        6          102  Pronunciation       Hard             Kpop
# 15        6          104        Grammar       Easy           Horror
# 1         1          102     Vocabulary     Medium             Kpop
# 8         3          101  Pronunciation       Hard            Anime
#
#    user_country user_age_group user_proficiency  rating
# 0         Japan          18-25         Beginner       4
# 17        Japan          36-45         Advanced       3
# 15        Japan          36-45         Advanced       4
# 1         Japan          18-25         Beginner       3
# 8           USA          36-45         Advanced       3

# %%
# Define model parameters
n_categories = df['category'].nunique()
n_difficulties = df['difficulty'].nunique()
n_cultural_contexts = df['cultural_context'].nunique()
n_countries = df['user_country'].nunique()
n_age_groups = df['user_age_group'].nunique()
n_proficiencies = df['user_proficiency'].nunique()

print(f"Number of categories: {n_categories}")
print(f"Number of difficulties: {n_difficulties}")
print(f"Number of cultural contexts: {n_cultural_contexts}")
print(f"Number of countries: {n_countries}")
print(f"Number of age groups: {n_age_groups}")
print(f"Number of proficiencies: {n_proficiencies}")
# Out:
# Number of categories: 3
# Number of difficulties: 3
# Number of cultural contexts: 4
# Number of countries: 5
# Number of age groups: 3
# Number of proficiencies: 3

# %%
# Content-based model architecture
category_input = Input(shape=(1,), name='category_input')
difficulty_input = Input(shape=(1,), name='difficulty_input')
cultural_context_input = Input(shape=(1,), name='cultural_context_input')
user_country_input = Input(shape=(1,), name='user_country_input')
user_age_group_input = Input(shape=(1,), name='user_age_group_input')
user_proficiency_input = Input(shape=(1,), name='user_proficiency_input')

print(category_input)
print(difficulty_input)
print(cultural_context_input)
print(user_country_input)
print(user_age_group_input)
print(user_proficiency_input)
# Out:
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, name=category_input>
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, name=difficulty_input>
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, name=cultural_context_input>
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, name=user_country_input>
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, name=user_age_group_input>
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, name=user_proficiency_input>

# %%
# Embedding layers
category_embedding = Embedding(n_categories, 10)(category_input)
difficulty_embedding = Embedding(n_difficulties, 5)(difficulty_input)
cultural_context_embedding = Embedding(n_cultural_contexts, 10)(cultural_context_input)
user_country_embedding = Embedding(n_countries, 10)(user_country_input)
user_age_group_embedding = Embedding(n_age_groups, 5)(user_age_group_input)
user_proficiency_embedding = Embedding(n_proficiencies, 5)(user_proficiency_input)

print(category_embedding)
print(difficulty_embedding)
print(cultural_context_embedding)
print(user_country_embedding)
print(user_age_group_embedding)
print(user_proficiency_embedding)
# Out:
# <KerasTensor shape=(None, 1, 10), dtype=float32, sparse=False, name=keras_tensor_45>
# <KerasTensor shape=(None, 1, 5), dtype=float32, sparse=False, name=keras_tensor_46>
# <KerasTensor shape=(None, 1, 10), dtype=float32, sparse=False, name=keras_tensor_47>
# <KerasTensor shape=(None, 1, 10), dtype=float32, sparse=False, name=keras_tensor_48>
# <KerasTensor shape=(None, 1, 5), dtype=float32, sparse=False, name=keras_tensor_49>
# <KerasTensor shape=(None, 1, 5), dtype=float32, sparse=False, name=keras_tensor_50>

# %%
# Concatenate all embeddings
concat = Concatenate()([
    Flatten()(category_embedding),
    Flatten()(difficulty_embedding),
    Flatten()(cultural_context_embedding),
    Flatten()(user_country_embedding),
    Flatten()(user_age_group_embedding),
    Flatten()(user_proficiency_embedding)
])

# %%
# Fully connected layers
dense1 = Dense(64, activation='relu')(concat)
bn1 = BatchNormalization()(dense1)
dense2 = Dense(32, activation='relu')(bn1)
bn2 = BatchNormalization()(dense2)
dropout1 = Dropout(0.3)(bn2)
dense3 = Dense(16, activation='relu')(dropout1)
bn3 = BatchNormalization()(dense3)
dense4 = Dense(8, activation='relu')(bn3)
bn4 = BatchNormalization()(dense4)
output = Dense(1)(bn4)  # Output layer for rating prediction

# Build and compile the model
model = Model(
    inputs=[category_input, difficulty_input, cultural_context_input, user_country_input, user_age_group_input, user_proficiency_input],
    outputs=output
)
model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(
    [train['category'], train['difficulty'], train['cultural_context'], train['user_country'], train['user_age_group'], train['user_proficiency']],
    train['rating'],
    epochs=200,
    batch_size=32,
    validation_split=0.1,
    callbacks=[early_stopping],
    verbose=1
)

# Example: Predict ratings for a user with certain characteristics
def predict_rating(user_features):
    prediction = model.predict([
        np.array([user_features['category']]),
        np.array([user_features['difficulty']]),
        np.array([user_features['cultural_context']]),
        np.array([user_features['user_country']]),
        np.array([user_features['user_age_group']]),
        np.array([user_features['user_proficiency']])
    ])
    return prediction[0][0]

# Example usage
user_features = {
    'category': df['category'].mode().iloc[0],
    'difficulty': df['difficulty'].mode().iloc[0],
    'cultural_context': df['cultural_context'].mode().iloc[0],
    'user_country': df['user_country'].mode().iloc[0],
    'user_age_group': df['user_age_group'].mode().iloc[0],
    'user_proficiency': df['user_proficiency'].mode().iloc[0]
}
predicted_rating = predict_rating(user_features)
print(f"Predicted rating: {predicted_rating}")
# Out:
# Epoch 1/200
# d:\WORKSPACE\content-based-filtering-scoreup\venv\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['category_input', 'difficulty_input', 'cultural_context_input', 'user_country_input', 'user_age_group_input', 'user_proficiency_input']. Received: the structure of inputs=('*', '*', '*', '*', '*', '*')
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 15.5238 - val_loss: 16.8832
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 13.8238 - val_loss: 16.8643
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 14.1466 - val_loss: 16.8155
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 13.4323 - val_loss: 16.7993
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 13.0523 - val_loss: 16.7678
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 13.7099 - val_loss: 16.7582
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.0272 - val_loss: 16.7548
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 13.2966 - val_loss: 16.7615
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 12.8589 - val_loss: 16.7457
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 13.0092 - val_loss: 16.7155
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.7318 - val_loss: 16.7064
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 13.3493 - val_loss: 16.7285
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.7346 - val_loss: 16.7178
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.6395 - val_loss: 16.7116
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 12.6161 - val_loss: 16.6840
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 12.8138 - val_loss: 16.6839
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 12.9904 - val_loss: 16.6736
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 12.8733 - val_loss: 16.6442
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 12.5038 - val_loss: 16.6019
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 12.5363 - val_loss: 16.5903
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 12.4446 - val_loss: 16.5770
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.5164 - val_loss: 16.5746
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.6937 - val_loss: 16.5576
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 12.2607 - val_loss: 16.5352
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 12.3696 - val_loss: 16.5127
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.3955 - val_loss: 16.4641
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.1922 - val_loss: 16.4283
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 12.3001 - val_loss: 16.4019
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 12.3082 - val_loss: 16.3881
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 12.5550 - val_loss: 16.3823
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.2215 - val_loss: 16.3792
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12.1972 - val_loss: 16.3813
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 12.1016 - val_loss: 16.3686
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 12.2328 - val_loss: 16.3337
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 12.0624 - val_loss: 16.3210
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 12.0571 - val_loss: 16.3089
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 12.1297 - val_loss: 16.3044
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 11.9936 - val_loss: 16.3018
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 11.9789 - val_loss: 16.2713
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 11.9035 - val_loss: 16.2435
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 11.6799 - val_loss: 16.2202
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 11.8251 - val_loss: 16.2053
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 11.7689 - val_loss: 16.1900
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 11.7840 - val_loss: 16.2015
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 11.7028 - val_loss: 16.1939
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 11.7494 - val_loss: 16.1784
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 11.6961 - val_loss: 16.1662
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 11.6198 - val_loss: 16.1653
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 11.8221 - val_loss: 16.1662
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 11.5228 - val_loss: 16.1609
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 11.4613 - val_loss: 16.1347
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 11.5966 - val_loss: 16.1067
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 11.4079 - val_loss: 16.0862
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 11.4900 - val_loss: 16.0542
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 11.4164 - val_loss: 16.0263
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 11.4575 - val_loss: 15.9797
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 11.5769 - val_loss: 15.9600
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 11.3221 - val_loss: 15.9442
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 11.3428 - val_loss: 15.9088
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 11.2449 - val_loss: 15.8640
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 11.3013 - val_loss: 15.8277
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 11.1324 - val_loss: 15.8297
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 11.1863 - val_loss: 15.8320
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 11.0764 - val_loss: 15.8018
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 11.2557 - val_loss: 15.7842
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 11.0243 - val_loss: 15.7668
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 11.0758 - val_loss: 15.7345
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 11.0687 - val_loss: 15.7072
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 11.0999 - val_loss: 15.6868
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 10.9615 - val_loss: 15.6592
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 10.9951 - val_loss: 15.6346
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 10.8945 - val_loss: 15.6179
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 11.0562 - val_loss: 15.5935
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 10.9383 - val_loss: 15.5959
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 10.9279 - val_loss: 15.5998
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 10.7357 - val_loss: 15.5965
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 10.7261 - val_loss: 15.5361
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 10.8402 - val_loss: 15.5095
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 10.6343 - val_loss: 15.4784
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 10.6441 - val_loss: 15.4482
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 10.7332 - val_loss: 15.4494
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 10.6385 - val_loss: 15.4426
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 10.5577 - val_loss: 15.4291
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 10.5159 - val_loss: 15.4160
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 10.5144 - val_loss: 15.4121
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 10.4480 - val_loss: 15.3818
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 10.4842 - val_loss: 15.3712
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 10.3587 - val_loss: 15.3538
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 10.4301 - val_loss: 15.3402
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 10.3862 - val_loss: 15.3355
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 10.2754 - val_loss: 15.3201
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 10.3103 - val_loss: 15.2829
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 10.3176 - val_loss: 15.2673
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 10.3036 - val_loss: 15.2701
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 10.1841 - val_loss: 15.2580
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 10.1733 - val_loss: 15.2455
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 10.1499 - val_loss: 15.2308
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 10.0747 - val_loss: 15.2115
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 10.0958 - val_loss: 15.1955
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 9.9857 - val_loss: 15.1899
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 9.9899 - val_loss: 15.1438
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 9.8927 - val_loss: 15.1121
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 9.8699 - val_loss: 15.0944
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 9.8286 - val_loss: 15.0872
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 9.8725 - val_loss: 15.0649
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 9.8262 - val_loss: 15.0569
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 9.7759 - val_loss: 15.0012
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 9.8226 - val_loss: 14.9729
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 9.6893 - val_loss: 14.9379
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 9.6816 - val_loss: 14.8969
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 9.6054 - val_loss: 14.8768
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 9.5741 - val_loss: 14.8250
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 9.5597 - val_loss: 14.7804
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 9.6510 - val_loss: 14.7437
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 9.4777 - val_loss: 14.6963
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 9.4234 - val_loss: 14.6329
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 9.4486 - val_loss: 14.5974
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 9.4226 - val_loss: 14.5554
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 9.3069 - val_loss: 14.5087
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 9.2939 - val_loss: 14.4689
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 9.2340 - val_loss: 14.4107
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 9.2406 - val_loss: 14.3510
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 9.2404 - val_loss: 14.3275
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 9.1661 - val_loss: 14.2887
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 9.0773 - val_loss: 14.2621
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 9.1660 - val_loss: 14.2174
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 9.0187 - val_loss: 14.1840
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 9.0250 - val_loss: 14.1571
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 8.9909 - val_loss: 14.1309
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 8.9598 - val_loss: 14.0899
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 9.0519 - val_loss: 14.0443
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 8.9311 - val_loss: 13.9992
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 8.7922 - val_loss: 13.9659
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 8.8521 - val_loss: 13.9241
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 8.7408 - val_loss: 13.8615
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 8.7449 - val_loss: 13.8227
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 8.6903 - val_loss: 13.7865
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 8.6210 - val_loss: 13.7658
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 8.5925 - val_loss: 13.7122
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 8.6855 - val_loss: 13.6826
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 8.5107 - val_loss: 13.6310
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 8.6403 - val_loss: 13.5934
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 8.4660 - val_loss: 13.5685
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 8.6467 - val_loss: 13.5348
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 8.3546 - val_loss: 13.5041
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 8.3891 - val_loss: 13.4727
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 8.3271 - val_loss: 13.4331
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 8.3674 - val_loss: 13.3873
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 8.1987 - val_loss: 13.3284
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 8.2175 - val_loss: 13.3104
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 8.1871 - val_loss: 13.2554
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 8.2121 - val_loss: 13.2450
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 8.1081 - val_loss: 13.2098
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 8.0391 - val_loss: 13.1714
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 8.0617 - val_loss: 13.1376
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 8.0007 - val_loss: 13.1121
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8.0018 - val_loss: 13.0539
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 7.8700 - val_loss: 13.0060
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 7.8512 - val_loss: 12.9655
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 7.8512 - val_loss: 12.9212
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 7.8800 - val_loss: 12.8690
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 7.7106 - val_loss: 12.7973
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 7.7433 - val_loss: 12.7401
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 7.6324 - val_loss: 12.6692
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 7.6708 - val_loss: 12.5869
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 7.6141 - val_loss: 12.5245
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 7.6345 - val_loss: 12.4485
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 7.5391 - val_loss: 12.3826
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 7.4813 - val_loss: 12.3172
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 7.4453 - val_loss: 12.2656
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.5637 - val_loss: 12.2495
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 7.3088 - val_loss: 12.2302
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 7.3217 - val_loss: 12.1997
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 7.3091 - val_loss: 12.1610
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 7.2219 - val_loss: 12.1077
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 7.2593 - val_loss: 12.0803
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 7.2022 - val_loss: 12.0310
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 7.1254 - val_loss: 11.9881
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 7.1519 - val_loss: 11.9243
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 7.0572 - val_loss: 11.8901
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 7.1137 - val_loss: 11.8201
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 6.9613 - val_loss: 11.7552
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 6.8853 - val_loss: 11.7118
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 6.9854 - val_loss: 11.6718
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 6.8187 - val_loss: 11.6438
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 6.8517 - val_loss: 11.5769
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 6.8124 - val_loss: 11.4931
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 6.7542 - val_loss: 11.4205
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 6.7180 - val_loss: 11.3451
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 6.7421 - val_loss: 11.2796
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 6.6563 - val_loss: 11.2246
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 6.5888 - val_loss: 11.1281
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 6.4876 - val_loss: 11.0260
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 6.5232 - val_loss: 10.9623
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 6.4400 - val_loss: 10.8954
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 6.4664 - val_loss: 10.8561
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 6.3640 - val_loss: 10.7816
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 6.3747 - val_loss: 10.7358
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 6.3153 - val_loss: 10.7246
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 6.2958 - val_loss: 10.7058
# d:\WORKSPACE\content-based-filtering-scoreup\venv\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['category_input', 'difficulty_input', 'cultural_context_input', 'user_country_input', 'user_age_group_input', 'user_proficiency_input']. Received: the structure of inputs=('*', '*', '*', '*', '*', '*')
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# Predicted rating: 0.879662275314331
